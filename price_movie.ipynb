# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel(r"C:\Users\pamuv\OneDrive\Desktop\New Microsoft Excel Worksheet.xlsx")

# %%
df.head()
# Out:
#    SI_No                      Movie_name  Hero_popularity_index  \
# 0      1                       Adipurush                     85
# 1      2                   Kalki 2898 AD                     92
# 2      3  PS-2 (Ponniyin Selvan: Part 2)                     90
# 3      4              Pushpa 2: The Rule                     91
# 4      5      Brahmastra Part One: Shiva                     88
#
#    Heroine_popularity_index                    Genre  Director_previous_hits  \
# 0                        78             Mythological                       4
# 1                        88           Sci-Fi_Fantasy                       7
# 2                        86  Historical_Period Drama                       7
# 3                        87         Action_Adventure                       6
# 4                        85           Sci-Fi_Fantasy                       6
#
#    trailer_views_in_Million  social_media_buzz_score  early_booking_rate  \
# 0                      1800                     0.93                78.0
# 1                      2500                     0.98                87.0
# 2                      2300                     0.97                85.0
# 3                      2400                     0.97                86.0
# 4                      1500                     0.95                70.0
#
#    total_budget  num_distributors  num_foreign_distributors screen_type  \
# 0         600.0                 8                         6        IMAX
# 1         600.0                10                         8        IMAX
# 2         550.0                 9                         7        IMAX
# 3         550.0                 9                         7        IMAX
# 4         500.0                 8                         6         4DX
#
#        cinema_class  is_weekend_release  is_festival_release  \
# 0  Tier-1-Multiplex                True                False
# 1  Tier-1-Multiplex                True                False
# 2  Tier-1-Multiplex                True                False
# 3  Tier-1-Multiplex                True                False
# 4  Tier-1-Multiplex                True                 True
#
#    days_until_festival  avg_ticket_price  \
# 0                    0               450
# 1                    3               580
# 2                    1               500
# 3                    1               560
# 4                    0               500
#
#                          languages_released
# 0  Hindi, Kannada, Malayalam, Tamil, Telugu
# 1  Hindi, Kannada, Malayalam, Tamil, Telugu
# 2  Hindi, Kannada, Malayalam, Tamil, Telugu
# 3  Hindi, Kannada, Malayalam, Tamil, Telugu
# 4  Hindi, Kannada, Malayalam, Tamil, Telugu

# %%
df.shape
# Out:
# (414, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SI_No                     414 non-null    int64
#  1   Movie_name                414 non-null    object
#  2   Hero_popularity_index     414 non-null    int64
#  3   Heroine_popularity_index  414 non-null    int64
#  4   Genre                     414 non-null    object
#  5   Director_previous_hits    414 non-null    int64
#  6   trailer_views_in_Million  414 non-null    int64
#  7   social_media_buzz_score   414 non-null    float64
#  8   early_booking_rate        414 non-null    float64
#  9   total_budget              414 non-null    float64
#  10  num_distributors          414 non-null    int64
#  11  num_foreign_distributors  414 non-null    int64
#  12  screen_type               414 non-null    object
#  13  cinema_class              414 non-null    object
#  14  is_weekend_release        414 non-null    bool
#  15  is_festival_release       414 non-null    bool
#  16  days_until_festival       414 non-null    int64
#  17  avg_ticket_price          414 non-null    int64
#  18  languages_released        414 non-null    object
# dtypes: bool(2), float64(3), int64(9), object(5)
# memory usage: 55.9+ KB

# %%
cols = ['Movie_name', 'Genre', 'screen_type', 'cinema_class', 'languages_released']
df[cols] = df[cols].astype("string")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SI_No                     414 non-null    int64
#  1   Movie_name                414 non-null    string
#  2   Hero_popularity_index     414 non-null    int64
#  3   Heroine_popularity_index  414 non-null    int64
#  4   Genre                     414 non-null    string
#  5   Director_previous_hits    414 non-null    int64
#  6   trailer_views_in_Million  414 non-null    int64
#  7   social_media_buzz_score   414 non-null    float64
#  8   early_booking_rate        414 non-null    float64
#  9   total_budget              414 non-null    float64
#  10  num_distributors          414 non-null    int64
#  11  num_foreign_distributors  414 non-null    int64
#  12  screen_type               414 non-null    string
#  13  cinema_class              414 non-null    string
#  14  is_weekend_release        414 non-null    bool
#  15  is_festival_release       414 non-null    bool
#  16  days_until_festival       414 non-null    int64
#  17  avg_ticket_price          414 non-null    int64
#  18  languages_released        414 non-null    string
# dtypes: bool(2), float64(3), int64(9), string(5)
# memory usage: 55.9 KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# SI_No                       0
# Movie_name                  0
# Hero_popularity_index       0
# Heroine_popularity_index    0
# Genre                       0
# Director_previous_hits      0
# trailer_views_in_Million    0
# social_media_buzz_score     0
# early_booking_rate          0
# total_budget                0
# num_distributors            0
# num_foreign_distributors    0
# screen_type                 0
# cinema_class                0
# is_weekend_release          0
# is_festival_release         0
# days_until_festival         0
# avg_ticket_price            0
# languages_released          0
# dtype: int64

# %%
newdf=df[df['early_booking_rate']<1][['SI_No','early_booking_rate']]
print(newdf)
# Out:
#      SI_No  early_booking_rate
# 53      54                0.75
# 54      55                0.80
# 60      61                0.78
# 67      68                0.70
# 68      69                0.74
# ..     ...                 ...
# 365    366                0.74
# 366    367                0.62
# 401    402                0.30
# 402    403                0.45
# 413    414                0.50
#
# [82 rows x 2 columns]

# %%
df.loc[df['early_booking_rate'] < 1, 'early_booking_rate'] *= 100
newdf2=df[df['early_booking_rate']<1][['SI_No','early_booking_rate']]
print(newdf2)
# Out:
# Empty DataFrame
# Columns: [SI_No, early_booking_rate]
# Index: []

# %%
df.loc[df['avg_ticket_price'] > 500, 'avg_ticket_price'] = 500
df['avg_ticket_price'].max()
# Out:
# 500

# %%
df.drop(columns=['SI_No'], inplace=True)
df.head()
# Out:
#                        Movie_name  Hero_popularity_index  \
# 0                       Adipurush                     85
# 1                   Kalki 2898 AD                     92
# 2  PS-2 (Ponniyin Selvan: Part 2)                     90
# 3              Pushpa 2: The Rule                     91
# 4      Brahmastra Part One: Shiva                     88
#
#    Heroine_popularity_index                    Genre  Director_previous_hits  \
# 0                        78             Mythological                       4
# 1                        88           Sci-Fi_Fantasy                       7
# 2                        86  Historical_Period Drama                       7
# 3                        87         Action_Adventure                       6
# 4                        85           Sci-Fi_Fantasy                       6
#
#    trailer_views_in_Million  social_media_buzz_score  early_booking_rate  \
# 0                      1800                     0.93                78.0
# 1                      2500                     0.98                87.0
# 2                      2300                     0.97                85.0
# 3                      2400                     0.97                86.0
# 4                      1500                     0.95                70.0
#
#    total_budget  num_distributors  num_foreign_distributors screen_type  \
# 0         600.0                 8                         6        IMAX
# 1         600.0                10                         8        IMAX
# 2         550.0                 9                         7        IMAX
# 3         550.0                 9                         7        IMAX
# 4         500.0                 8                         6         4DX
#
#        cinema_class  is_weekend_release  is_festival_release  \
# 0  Tier-1-Multiplex                True                False
# 1  Tier-1-Multiplex                True                False
# 2  Tier-1-Multiplex                True                False
# 3  Tier-1-Multiplex                True                False
# 4  Tier-1-Multiplex                True                 True
#
#    days_until_festival  avg_ticket_price  \
# 0                    0               450
# 1                    3               500
# 2                    1               500
# 3                    1               500
# 4                    0               500
#
#                          languages_released
# 0  Hindi, Kannada, Malayalam, Tamil, Telugu
# 1  Hindi, Kannada, Malayalam, Tamil, Telugu
# 2  Hindi, Kannada, Malayalam, Tamil, Telugu
# 3  Hindi, Kannada, Malayalam, Tamil, Telugu
# 4  Hindi, Kannada, Malayalam, Tamil, Telugu

# %%
cols = ['screen_type', 'cinema_class', 'Genre']
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for ax, col in zip(axes, cols):
    counts = df[col].value_counts()
    sns.barplot(
        x=counts.values,
        y=counts.index,
        hue=counts.index,       
        palette='crest',
        legend=False,
        ax=ax
    )
    ax.set_title(f'{col} Frequency')
    ax.set_xlabel('Frequency')
    ax.set_ylabel(col)

plt.tight_layout()
plt.show()

# %%
cols = [
    'Hero_popularity_index',
    'Heroine_popularity_index',
    'trailer_views_in_Million',
    'social_media_buzz_score',
    'early_booking_rate',
    'total_budget',
    'num_distributors',
    'num_foreign_distributors',
]

# Set up the grid of subplots
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(20, 10))

# Flatten axes for easy iteration
axes = axes.flatten()

# Loop through columns and plot
for i, col in enumerate(cols):
    sns.histplot(data=df, x=col, kde=True, ax=axes[i], color='skyblue')
    axes[i].set_title(f'Distribution of {col}')
    axes[i].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
#trailer view and total budget is more right skewed so log transform
#rest leftsqued data if squared it may reude left squeness but it will worse the left most data where data is maximum


# Apply log1p (i.e., log(1 + x)) to avoid issues with zeros
df['trailer_views_log'] = np.log1p(df['trailer_views_in_Million'])
df['total_budget_log'] = np.log1p(df['total_budget'])

cols = ['trailer_views_in_Million', 'trailer_views_log', 'total_budget', 'total_budget_log']

plt.figure(figsize=(12, 8))
for i, col in enumerate(cols, 1):
    plt.subplot(2, 2, i)
    sns.histplot(df[col], kde=True, color='skyblue')
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 4))
sns.scatterplot(x=df['avg_ticket_price'], y=df.index , color='red')
plt.title('Average Ticket Price Scatter Plot')
plt.ylabel('Index')
plt.xlabel('Average Ticket Price')
plt.grid(True)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(5, 4))
sns.histplot(data=df, x='avg_ticket_price', bins=30, kde=True, color='green')
plt.title('Histogram of Average Ticket Price')
plt.xlabel('Average Ticket Price')
plt.ylabel('Frequency')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def boxplots_vertical_grid(df):
    numeric_cols = df.select_dtypes(include='number').columns
    num_plots = len(numeric_cols)
    
    rows, cols = 2, 6
    plt.figure(figsize=(22, 8))  
    
    for i, col in enumerate(numeric_cols):
        if i >= rows * cols:
            break 
        plt.subplot(rows, cols, i + 1)
        sns.boxplot(data=df, y=col, color='lightblue')  
        plt.title(f'{col}', fontsize=10)
        plt.ylabel('')
        plt.xlabel('')
        plt.xticks(rotation=90)

    plt.tight_layout()
    plt.show()

# Call the function
boxplots_vertical_grid(df)

# %%
# List of features to compare with avg_ticket_price
features = [
    'Hero_popularity_index', 'Heroine_popularity_index', 'Director_previous_hits',
    'trailer_views_in_Million', 'social_media_buzz_score', 'early_booking_rate',
    'total_budget', 'num_distributors', 'num_foreign_distributors', 'days_until_festival'
]

# Joint plots of each feature with avg_ticket_price
for col in features:
    sns.jointplot(data=df, x=col, y='avg_ticket_price', kind='scatter', height=6)
    plt.suptitle(f'Joint Plot: {col} vs Avg Ticket Price', y=1.02)
    plt.show()

# %%
#from univarite and bivarite analysis director hits  is abnormal so lets not take that while trainng OUTLINER,

# %%
plt.figure(figsize=(16, 6))

# Plot 1: Genre vs avg_ticket_price with cinema_class as hue 
plt.subplot(1, 2, 1)
sns.barplot(data=df, x='Genre', y='avg_ticket_price',hue='cinema_class')
plt.title('Avg Ticket Price by Genre & Cinema Class')
plt.xticks(rotation=45)
plt.tight_layout()

# Plot 2: Screen Type vs avg_ticket_price with cinema_class as hue
plt.subplot(1, 2, 2)
sns.barplot(data=df, x='screen_type', y='avg_ticket_price', hue='cinema_class', estimator='mean')
plt.title('Avg Ticket Price by Screen Type & Cinema Class')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(16, 6))

# Boxplot 1: Genre vs avg_ticket_price
plt.subplot(1, 2, 1)
sns.boxplot(data=df, x='Genre', y='avg_ticket_price')
plt.title('Boxplot of Avg Ticket Price by Genre & Cinema Class')
plt.xticks(rotation=45)
plt.tight_layout()

# Boxplot 2: Screen Type vs avg_ticket_price
plt.subplot(1, 2, 2)
sns.boxplot(data=df, x='screen_type', y='avg_ticket_price', hue='cinema_class')
plt.title('Boxplot of Avg Ticket Price by Screen Type & Cinema Class')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
sns.histplot(data=df, x='avg_ticket_price', hue='Genre', kde=True, multiple='stack')
plt.title('Distribution of Avg Ticket Price by Genre')

# Distplot 2: Screen Type
plt.subplot(1, 2, 2)
sns.histplot(data=df, x='avg_ticket_price', hue='screen_type', kde=True, multiple='stack')
plt.title('Distribution of Avg Ticket Price by Screen Type')

plt.tight_layout()
plt.show()

# %%
# Strip whitespace, split by ',' and count the number of languages
df['num_languages'] = df['languages_released'].apply(lambda x: len(x.split(',')))
df['is_weekend_release'] = df['is_weekend_release'].astype(int)
df['is_festival_release'] = df['is_festival_release'].astype(int)

df.sample(5)
# Out:
#                    Movie_name  Hero_popularity_index  \
# 161        Kishkindha Kaandam                     86
# 30   Avatar: The Way of Water                     90
# 247               Kabir Singh                     85
# 322              Mungaru Male                     83
# 167        Ennu Ninte Moideen                     71
#
#      Heroine_popularity_index                    Genre  \
# 161                        82  Historical_Period Drama
# 30                         88           Sci-Fi_Fantasy
# 247                        78                    Drama
# 322                        80                  Romance
# 167                        66                  Romance
#
#      Director_previous_hits  trailer_views_in_Million  \
# 161                       4                       700
# 30                        8                      2800
# 247                       3                      1200
# 322                       4                      1200
# 167                       1                      1050
#
#      social_media_buzz_score  early_booking_rate  total_budget  \
# 161                     0.88                72.0         100.0
# 30                      0.99                85.0         350.0
# 247                     0.92                75.0          60.0
# 322                     0.91                78.0          40.0
# 167                     0.79                64.0         100.0
#
#      num_distributors  ...  screen_type      cinema_class is_weekend_release  \
# 161                 5  ...      Regular            Tier-1                  1
# 30                  9  ...         IMAX  Tier-1-Multiplex                  1
# 247                 4  ...         IMAX  Tier-1-Multiplex                  1
# 322                 5  ...      Regular  Tier-1-Multiplex                  1
# 167                 2  ...         IMAX  Tier-1-Multiplex                  1
#
#      is_festival_release  days_until_festival  avg_ticket_price  \
# 161                    0                    8               340
# 30                     0                    3               500
# 247                    0                    6               320
# 322                    0                    6               350
# 167                    0                   19               320
#
#                    languages_released trailer_views_log  total_budget_log  \
# 161                         Malayalam          6.552508          4.615121
# 30                     English, Hindi          7.937732          5.860786
# 247  Hindi, Kannada, Malayalam, Tamil          7.090910          4.110874
# 322                           Kannada          7.090910          3.713572
# 167                  Malayalam, Tamil          6.957497          4.615121
#
#      num_languages
# 161              1
# 30               2
# 247              4
# 322              1
# 167              2
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#        Hero_popularity_index  Heroine_popularity_index  \
# count             414.000000                414.000000
# mean               80.265700                 77.396135
# std                 6.023516                  5.498632
# min                55.000000                 55.000000
# 25%                78.000000                 75.000000
# 50%                80.000000                 78.000000
# 75%                84.000000                 81.000000
# max                95.000000                 90.000000
#
#        Director_previous_hits  trailer_views_in_Million  \
# count              414.000000                414.000000
# mean                 3.461353                818.260870
# std                  1.685202                469.584711
# min                  0.000000                 20.000000
# 25%                  2.000000                480.000000
# 50%                  3.000000                785.000000
# 75%                  4.000000                950.000000
# max                 15.000000               2800.000000
#
#        social_media_buzz_score  early_booking_rate  total_budget  \
# count               414.000000          414.000000    414.000000
# mean                  0.865411           66.582609    120.886715
# std                   0.066217           11.284041    116.280467
# min                   0.420000           15.000000      1.100000
# 25%                   0.850000           61.125000     42.000000
# 50%                   0.880000           69.000000     80.000000
# 75%                   0.900000           74.000000    150.000000
# max                   0.990000           87.000000    600.000000
#
#        num_distributors  num_foreign_distributors  is_weekend_release  \
# count        414.000000                414.000000          414.000000
# mean           4.444444                  2.362319            0.753623
# std            1.617266                  1.375725            0.431422
# min            1.000000                  0.000000            0.000000
# 25%            3.000000                  1.000000            1.000000
# 50%            4.000000                  2.000000            1.000000
# 75%            5.000000                  3.000000            1.000000
# max           10.000000                  8.000000            1.000000
#
#        is_festival_release  days_until_festival  avg_ticket_price  \
# count           414.000000           414.000000        414.000000
# mean              0.096618             7.502415        336.714976
# std               0.295795             4.850176         76.793052
# min               0.000000             0.000000        100.000000
# 25%               0.000000             5.000000        290.000000
# 50%               0.000000             7.000000        330.000000
# 75%               0.000000            10.000000        380.000000
# max               1.000000            30.000000        500.000000
#
#        trailer_views_log  total_budget_log  num_languages
# count         414.000000        414.000000     414.000000
# mean            6.520471          4.423916       1.884058
# std             0.686218          0.877327       1.313402
# min             3.044522          0.741937       1.000000
# 25%             6.175867          3.761200       1.000000
# 50%             6.666937          4.394449       1.000000
# 75%             6.857514          5.017280       2.000000
# max             7.937732          6.398595       5.000000

# %%
df.corr(numeric_only=True)
# Out:
#                           Hero_popularity_index  Heroine_popularity_index  \
# Hero_popularity_index                  1.000000                  0.907553
# Heroine_popularity_index               0.907553                  1.000000
# Director_previous_hits                 0.590667                  0.567114
# trailer_views_in_Million               0.650006                  0.557368
# social_media_buzz_score                0.854463                  0.804342
# early_booking_rate                     0.788699                  0.744484
# total_budget                           0.549852                  0.478556
# num_distributors                       0.777997                  0.719391
# num_foreign_distributors               0.735489                  0.664679
# is_weekend_release                     0.478080                  0.407669
# is_festival_release                    0.090197                  0.080619
# days_until_festival                   -0.613904                 -0.558757
# avg_ticket_price                       0.771944                  0.722847
# trailer_views_log                      0.759378                  0.683007
# total_budget_log                       0.618590                  0.551829
# num_languages                          0.369641                  0.280293
#
#                           Director_previous_hits  trailer_views_in_Million  \
# Hero_popularity_index                   0.590667                  0.650006
# Heroine_popularity_index                0.567114                  0.557368
# Director_previous_hits                  1.000000                  0.465729
# trailer_views_in_Million                0.465729                  1.000000
# social_media_buzz_score                 0.535009                  0.693161
# early_booking_rate                      0.397440                  0.778230
# total_budget                            0.549024                  0.663444
# num_distributors                        0.708166                  0.657644
# num_foreign_distributors                0.675514                  0.735631
# is_weekend_release                      0.293268                  0.496270
# is_festival_release                     0.221236                 -0.070258
# days_until_festival                    -0.499149                 -0.400695
# avg_ticket_price                        0.543667                  0.794469
# trailer_views_log                       0.466808                  0.879410
# total_budget_log                        0.571204                  0.551513
# num_languages                           0.439929                  0.486247
#
#                           social_media_buzz_score  early_booking_rate  \
# Hero_popularity_index                    0.854463            0.788699
# Heroine_popularity_index                 0.804342            0.744484
# Director_previous_hits                   0.535009            0.397440
# trailer_views_in_Million                 0.693161            0.778230
# social_media_buzz_score                  1.000000            0.913394
# early_booking_rate                       0.913394            1.000000
# total_budget                             0.498832            0.437236
# num_distributors                         0.736505            0.643668
# num_foreign_distributors                 0.691027            0.625865
# is_weekend_release                       0.540912            0.559509
# is_festival_release                      0.040000           -0.076391
# days_until_festival                     -0.683917           -0.558329
# avg_ticket_price                         0.837413            0.842084
# trailer_views_log                        0.883476            0.913854
# total_budget_log                         0.623930            0.490418
# num_languages                            0.303457            0.211909
#
#                           total_budget  num_distributors  \
# Hero_popularity_index         0.549852          0.777997
# Heroine_popularity_index      0.478556          0.719391
# Director_previous_hits        0.549024          0.708166
# trailer_views_in_Million      0.663444          0.657644
# social_media_buzz_score       0.498832          0.736505
# early_booking_rate            0.437236          0.643668
# total_budget                  1.000000          0.807901
# num_distributors              0.807901          1.000000
# num_foreign_distributors      0.843966          0.944981
# is_weekend_release            0.292701          0.421062
# is_festival_release           0.095355          0.147908
# days_until_festival          -0.418543         -0.669977
# avg_ticket_price              0.729358          0.842706
# trailer_views_log             0.514446          0.631677
# total_budget_log              0.888969          0.847062
# num_languages                 0.608906          0.509920
#
#                           num_foreign_distributors  is_weekend_release  \
# Hero_popularity_index                     0.735489            0.478080
# Heroine_popularity_index                  0.664679            0.407669
# Director_previous_hits                    0.675514            0.293268
# trailer_views_in_Million                  0.735631            0.496270
# social_media_buzz_score                   0.691027            0.540912
# early_booking_rate                        0.625865            0.559509
# total_budget                              0.843966            0.292701
# num_distributors                          0.944981            0.421062
# num_foreign_distributors                  1.000000            0.420020
# is_weekend_release                        0.420020            1.000000
# is_festival_release                       0.122021           -0.078646
# days_until_festival                      -0.610855           -0.510019
# avg_ticket_price                          0.834545            0.582113
# trailer_views_log                         0.633101            0.588372
# total_budget_log                          0.818883            0.346487
# num_languages                             0.582106            0.240041
#
#                           is_festival_release  days_until_festival  \
# Hero_popularity_index                0.090197            -0.613904
# Heroine_popularity_index             0.080619            -0.558757
# Director_previous_hits               0.221236            -0.499149
# trailer_views_in_Million            -0.070258            -0.400695
# social_media_buzz_score              0.040000            -0.683917
# early_booking_rate                  -0.076391            -0.558329
# total_budget                         0.095355            -0.418543
# num_distributors                     0.147908            -0.669977
# num_foreign_distributors             0.122021            -0.610855
# is_weekend_release                  -0.078646            -0.510019
# is_festival_release                  1.000000            -0.506481
# days_until_festival                 -0.506481             1.000000
# avg_ticket_price                     0.065172            -0.624191
# trailer_views_log                   -0.047267            -0.518722
# total_budget_log                     0.151285            -0.552541
# num_languages                        0.128624            -0.309355
#
#                           avg_ticket_price  trailer_views_log  \
# Hero_popularity_index             0.771944           0.759378
# Heroine_popularity_index          0.722847           0.683007
# Director_previous_hits            0.543667           0.466808
# trailer_views_in_Million          0.794469           0.879410
# social_media_buzz_score           0.837413           0.883476
# early_booking_rate                0.842084           0.913854
# total_budget                      0.729358           0.514446
# num_distributors                  0.842706           0.631677
# num_foreign_distributors          0.834545           0.633101
# is_weekend_release                0.582113           0.588372
# is_festival_release               0.065172          -0.047267
# days_until_festival              -0.624191          -0.518722
# avg_ticket_price                  1.000000           0.822141
# trailer_views_log                 0.822141           1.000000
# total_budget_log                  0.771412           0.535386
# num_languages                     0.436976           0.337973
#
#                           total_budget_log  num_languages
# Hero_popularity_index             0.618590       0.369641
# Heroine_popularity_index          0.551829       0.280293
# Director_previous_hits            0.571204       0.439929
# trailer_views_in_Million          0.551513       0.486247
# social_media_buzz_score           0.623930       0.303457
# early_booking_rate                0.490418       0.211909
# total_budget                      0.888969       0.608906
# num_distributors                  0.847062       0.509920
# num_foreign_distributors          0.818883       0.582106
# is_weekend_release                0.346487       0.240041
# is_festival_release               0.151285       0.128624
# days_until_festival              -0.552541      -0.309355
# avg_ticket_price                  0.771412       0.436976
# trailer_views_log                 0.535386       0.337973
# total_budget_log                  1.000000       0.515118
# num_languages                     0.515118       1.000000

# %%
# Compute correlation matrix
corr_matrix = df.corr(numeric_only=True)

# Set the figure size
plt.figure(figsize=(12, 8))

# Plot the heatmap
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)

# Display the plot
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
#manuel label encodding
# Manual ordinal mapping for screen_type
screen_type_map = {
    'Regular': 0,
    'IMAX': 1,
    '4DX': 2
}
df['screen_type_encoded'] = df['screen_type'].map(screen_type_map)

# Manual ordinal mapping for cinema_class
cinema_class_map = {
    'Tier-2': 0,
    'Tier-1': 1,
    'Tier-1-Multiplex': 2
}
df['cinema_class_encoded'] = df['cinema_class'].map(cinema_class_map)
df.head()
# Out:
#                        Movie_name  Hero_popularity_index  \
# 0                       Adipurush                     85
# 1                   Kalki 2898 AD                     92
# 2  PS-2 (Ponniyin Selvan: Part 2)                     90
# 3              Pushpa 2: The Rule                     91
# 4      Brahmastra Part One: Shiva                     88
#
#    Heroine_popularity_index                    Genre  Director_previous_hits  \
# 0                        78             Mythological                       4
# 1                        88           Sci-Fi_Fantasy                       7
# 2                        86  Historical_Period Drama                       7
# 3                        87         Action_Adventure                       6
# 4                        85           Sci-Fi_Fantasy                       6
#
#    trailer_views_in_Million  social_media_buzz_score  early_booking_rate  \
# 0                      1800                     0.93                78.0
# 1                      2500                     0.98                87.0
# 2                      2300                     0.97                85.0
# 3                      2400                     0.97                86.0
# 4                      1500                     0.95                70.0
#
#    total_budget  num_distributors  ...  is_weekend_release  \
# 0         600.0                 8  ...                   1
# 1         600.0                10  ...                   1
# 2         550.0                 9  ...                   1
# 3         550.0                 9  ...                   1
# 4         500.0                 8  ...                   1
#
#   is_festival_release days_until_festival  avg_ticket_price  \
# 0                   0                   0               450
# 1                   0                   3               500
# 2                   0                   1               500
# 3                   0                   1               500
# 4                   1                   0               500
#
#                          languages_released  trailer_views_log  \
# 0  Hindi, Kannada, Malayalam, Tamil, Telugu           7.496097
# 1  Hindi, Kannada, Malayalam, Tamil, Telugu           7.824446
# 2  Hindi, Kannada, Malayalam, Tamil, Telugu           7.741099
# 3  Hindi, Kannada, Malayalam, Tamil, Telugu           7.783641
# 4  Hindi, Kannada, Malayalam, Tamil, Telugu           7.313887
#
#    total_budget_log num_languages  screen_type_encoded  cinema_class_encoded
# 0          6.398595             5                    1                     2
# 1          6.398595             5                    1                     2
# 2          6.311735             5                    1                     2
# 3          6.311735             5                    1                     2
# 4          6.216606             5                    2                     2
#
# [5 rows x 23 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder( sparse_output=False)
genre_encoded = encoder.fit_transform(df[['Genre']])
df_encoded = pd.concat([df.drop('Genre', axis=1), 
                       pd.DataFrame(genre_encoded, columns=encoder.get_feature_names_out(['Genre']))], 
                       axis=1)
encoder.get_feature_names_out(['Genre'])
# Out:
# array(['Genre_Action_Adventure', 'Genre_Biopic_Inspirational',
#        'Genre_Comedy_family', 'Genre_Drama',
#        'Genre_Historical_Period Drama', 'Genre_Horror',
#        'Genre_Mythological', 'Genre_Romance', 'Genre_Sci-Fi_Fantasy',
#        'Genre_Thriller_Crime', 'Genre_War_sports'], dtype=object)

# %%
dropcol = [
    'Movie_name',
    'Director_previous_hits',
    'total_budget',
    'trailer_views_in_Million',
    'screen_type',
    'cinema_class',
    'languages_released',
    'days_until_festival'
]

# Drop only if columns exist
df_encoded = df_encoded.drop(columns=dropcol, errors='ignore')

# Move 'avg_ticket_price' to the end if it exists
if 'avg_ticket_price' in df_encoded.columns:
    target_col = df_encoded['avg_ticket_price']
    df_encoded = df_encoded.drop(columns=['avg_ticket_price'])
    df_encoded['avg_ticket_price'] = target_col

# %%
df_encoded.sample(5)
# Out:
#      Hero_popularity_index  Heroine_popularity_index  social_media_buzz_score  \
# 108                     85                        80                     0.93
# 348                     81                        78                     0.88
# 282                     83                        76                     0.89
# 381                     79                        77                     0.87
# 139                     88                        85                     0.90
#
#      early_booking_rate  num_distributors  num_foreign_distributors  \
# 108                77.0                 6                         4
# 348                74.0                 4                         2
# 282                74.0                 4                         2
# 381                69.0                 3                         1
# 139                75.0                 5                         3
#
#      is_weekend_release  is_festival_release  trailer_views_log  \
# 108                   1                    0           7.170888
# 348                   1                    0           6.857514
# 282                   1                    0           6.957497
# 381                   1                    0           6.734592
# 139                   0                    1           6.660575
#
#      total_budget_log  ...  Genre_Comedy_family  Genre_Drama  \
# 108          5.017280  ...                  0.0          0.0
# 348          3.583519  ...                  0.0          0.0
# 282          3.931826  ...                  0.0          1.0
# 381          3.367296  ...                  0.0          0.0
# 139          4.795791  ...                  0.0          1.0
#
#      Genre_Historical_Period Drama  Genre_Horror  Genre_Mythological  \
# 108                            1.0           0.0                 0.0
# 348                            0.0           0.0                 0.0
# 282                            0.0           0.0                 0.0
# 381                            0.0           0.0                 0.0
# 139                            0.0           0.0                 0.0
#
#      Genre_Romance  Genre_Sci-Fi_Fantasy  Genre_Thriller_Crime  \
# 108            0.0                   0.0                   0.0
# 348            1.0                   0.0                   0.0
# 282            0.0                   0.0                   0.0
# 381            1.0                   0.0                   0.0
# 139            0.0                   0.0                   0.0
#
#      Genre_War_sports  avg_ticket_price
# 108               0.0               390
# 348               0.0               330
# 282               0.0               340
# 381               0.0               330
# 139               0.0               320
#
# [5 rows x 25 columns]

# %%
corr_matrix2= df_encoded.corr(numeric_only=True)
# Or only correlation with target column
target_corr = corr_matrix2["avg_ticket_price"].sort_values(ascending=False)
print(target_corr)
# Out:
# avg_ticket_price                 1.000000
# num_distributors                 0.842706
# early_booking_rate               0.842084
# social_media_buzz_score          0.837413
# num_foreign_distributors         0.834545
# trailer_views_log                0.822141
# Hero_popularity_index            0.771944
# total_budget_log                 0.771412
# Heroine_popularity_index         0.722847
# screen_type_encoded              0.609673
# cinema_class_encoded             0.601403
# is_weekend_release               0.582113
# num_languages                    0.436976
# Genre_Action_Adventure           0.272282
# Genre_Historical_Period Drama    0.153415
# Genre_Sci-Fi_Fantasy             0.085788
# is_festival_release              0.065172
# Genre_Mythological               0.038040
# Genre_War_sports                 0.005320
# Genre_Thriller_Crime            -0.014875
# Genre_Biopic_Inspirational      -0.021801
# Genre_Comedy_family             -0.066997
# Genre_Horror                    -0.091720
# Genre_Romance                   -0.119694
# Genre_Drama                     -0.198981
# Name: avg_ticket_price, dtype: float64
